# %% [markdown]
# # Pandas as a Database
# Rather than installing postrgres and Django and configuring all that You can just use a Pandas collection of DataFrame tables as your database Lets see if we can find a "primary key" that we can use to connect a couple of these tables
# Thanks [Jeremy Tanner](https://twitter.com/Penguin) for the max_rows trick

# %%
import pandas as pd
pd.set_option('display.max_rows', 6)

# %%
candidates = pd.DataFrame.from_csv('public.raw_candidate_filings.csv').sort_values(by='last_name')  # id_nmbr
candidates[[col for col in candidates.columns if 'name' in col or 'id' in col]]
# Out:
#                        id_nbr  \
# election_txt
# 2012 Primary Election    1914
# 2012 Primary Election    1461
# 2012 General Election    1205
# ...                       ...
# 2010 General Election    1215
# 2014 Primary Election    1236
# 2014 General Election    1236
#
#                                                         candidate_office  \
# election_txt
# 2012 Primary Election               District Attorney, Hood River County
# 2012 Primary Election  Judge of the Circuit Court, 3rd District, Posi...
# 2012 General Election                 State Representative, 5th District
# ...                                                                  ...
# 2010 General Election                State Representative, 15th District
# 2014 Primary Election                State Representative, 36th District
# 2014 General Election                State Representative, 36th District
#
#                        candidate_file_rsn  cand_ballot_name_txt prfx_name_cd  \
# election_txt
# 2012 Primary Election               12291           Brian Aaron          NaN
# 2012 Primary Election               11374         Donald D Abar          NaN
# 2012 General Election               13540  Sandra A Abercrombie          NaN
# ...                                   ...                   ...          ...
# 2010 General Election                9725            Andy Olson          NaN
# 2014 Primary Election               14997   Jennifer Williamson          NaN
# 2014 General Election               15488   Jennifer Williamson          NaN
#
#                       first_name mdle_name    last_name sufx_name  \
# election_txt
# 2012 Primary Election      Brian   Douglas        Aaron       NaN
# 2012 Primary Election     Donald         D         Abar       NaN
# 2012 General Election     Sandra         A  Abercrombie       NaN
# ...                          ...       ...          ...       ...
# 2010 General Election       andy       NaN        olson       NaN
# 2014 Primary Election   jennifer         a   williamson       NaN
# 2014 General Election   jennifer         a   williamson       NaN
#
#                       mailing_city_name      residence_addr_line_1  \
# election_txt
# 2012 Primary Election        Hood River           1822 Columbia St
# 2012 Primary Election             Salem  Exempt from public record
# 2012 General Election           Medford                  1935 Hart
# ...                                 ...                        ...
# 2010 General Election            Albany  34499 Mountain View Pl NE
# 2014 Primary Election          Portland                615 NW 22nd
# 2014 General Election          Portland                615 NW 22nd
#
#                       residence_addr_line_2 residence_city_name  \
# election_txt
# 2012 Primary Election                   NaN          Hood River
# 2012 Primary Election                   NaN                 NaN
# 2012 General Election                   NaN             Medford
# ...                                     ...                 ...
# 2010 General Election                   NaN              Albany
# 2014 Primary Election                   NaN            Portland
# 2014 General Election                   NaN            Portland
#
#                       residence_st_cd  residence_zip_code  \
# election_txt
# 2012 Primary Election              OR               97031
# 2012 Primary Election             NaN                 NaN
# 2012 General Election              OR               97501
# ...                               ...                 ...
# 2010 General Election              OR               97322
# 2014 Primary Election              OR               97210
# 2014 General Election              OR               97210
#
#                        residence_zip_plus_four
# election_txt
# 2012 Primary Election                      NaN
# 2012 Primary Election                      NaN
# 2012 General Election                      NaN
# ...                                        ...
# 2010 General Election                      NaN
# 2014 Primary Election                      NaN
# 2014 General Election                      NaN
#
# [2353 rows x 16 columns]

# %%
pacs = pd.DataFrame.from_csv('public.raw_committees.csv').sort_values(by='committee_name')  # no ID that I can find
pacs[[col for col in pacs.columns if 'name' in col or 'id' in col or 'type' in col]]
# Out:
#                               committee_name committee_type committee_subtype  \
# committee_id
# 5505                          13 Enviros PAC            PAC     Miscellaneous
# 15790               19thofJune Green Chapter            PAC   Political Party
# 13986                 2020 Vision for Oregon            PAC           Measure
# ...                                      ...            ...               ...
# 12896         shepherd for sheriff committee             CC               NaN
# 16132                 susiejonesformhccboard             CC               NaN
# 9406          von Nagy for Beaverton Schools             CC               NaN
#
#                                 candidate_office candidate_office_group  \
# committee_id
# 5505                                         NaN                    NaN
# 15790                                        NaN                    NaN
# 13986                                        NaN                    NaN
# ...                                          ...                    ...
# 12896                             Klamath County         County Sheriff
# 16132         Mt. Hood Community College, Zone 1               Director
# 9406           Beaverton School District, Zone 4               Director
#
#              treasurer_first_name treasurer_last_name candidate_first_name  \
# committee_id
# 5505                        Kevin               Neely
# 15790                      Jorden             Leonard
# 13986                          Al               LeMay
# ...                           ...                 ...                  ...
# 12896                       peter            shepherd                peter
# 16132                      Samuel              Solano                Susie
# 9406                         Ivan            von Nagy               Denise
#
#              candidate_last_name                   candidate_maling_address  \
# committee_id
# 5505                                                                    NaN
# 15790                                                                   NaN
# 13986                                                                   NaN
# ...                          ...                                        ...
# 12896                   shepherd  5640 Jennifer Lane Klamath Falls OR 97603
# 16132                      Jones           404 SE Hale Dr. Gresham OR 97080
# 9406                    von Nagy        7510 SW 189th Avenue Aloha OR 97007
#
#              candidate_work_phone  candidate_residence_phone  candidate_fax  \
# committee_id
# 5505                          NaN                        NaN            NaN
# 15790                         NaN                        NaN            NaN
# 13986                         NaN                        NaN            NaN
# ...                           ...                        ...            ...
# 12896               (541)885-6629                        NaN            NaN
# 16132                503 621-6316                        NaN  (503)661-3924
# 9406                          NaN                        NaN            NaN
#
#                          candidate_email
# committee_id
# 5505                                 NaN
# 15790                                NaN
# 13986                                NaN
# ...                                  ...
# 12896                   shepstir@msn.com
# 16132         susie.jones52@frontier.com
# 9406                                 NaN
#
# [2596 rows x 14 columns]

# %%
pacs_scraped = pd.DataFrame.from_csv('public.raw_committees_scraped.csv', index_col='id').sort_values(by='name')  # id
pacs_scraped
# Out:
#                                              name acronym       pac_type  \
# id
# 17268          21st Century Veterans for Progress     NaN  Miscellaneous
# 15508  A Better Choice Political Action Committee     NaN            NaN
# ...                                           ...     ...            ...
# 17425                                  reelectbob     NaN            NaN
# 13147                       unbiased city council     NaN            NaN
#
#           filing_effective_from      filing_type  \
# id
# 17268     01/15/2015 to present         Original
# 15508  06/10/2014 to 06/10/2014  Discontinuation
# ...                         ...              ...
# 17425     05/14/2015 to present         Original
# 13147  05/18/2010 to 05/18/2010  Discontinuation
#
#                                                  address campaign_phone  \
# id
# 17268       1320 Edgewater St. Suite 230 Salem, OR 97304  (971)273-0114
# 15508               439 Pyle Drive Grants Pass, OR 97527  (541)659-4313
# ...                                                  ...            ...
# 17425  59157 Cooperspur CT Saint Helens, OR 97051 - 9311  (503)397-3023
# 13147    445 kalapuya way cottage grove, OR 97424 - 1385  (541)942-6113
#
#         treasurer_name                          treasurer_mailing_address  \
# id
# 17268  Jeffery D Julum       1320 Edgewater St. Suite 230 Salem, OR 97304
# 15508  Jack A Brown Jr      1252 Redwood Avenue #68 Grants Pass, OR 97527
# ...                ...                                                ...
# 17425   Robert J Braud  59157 Cooperspur CT Saint Helens, OR 97051 - 9311
# 13147     diane conrad    445 kalapuya way cottage grove, OR 97424 - 1385
#
#       treasurer_work_phone_home_phone_fax      ...        \
# id                                             ...
# 17268         (703)944-8119 (503)364-1933      ...
# 15508         (541)659-4313 (541)476-7001      ...
# ...                                   ...      ...
# 17425         (503)397-3023 (503)397-0181      ...
# 13147                                 NaN      ...
#
#                              candidate_candidate_address  \
# id
# 17268                                                NaN
# 15508                                                NaN
# ...                                                  ...
# 17425  59157 Cooperspur CT Saint Helens, OR 97051 - 9311
# 13147                                                NaN
#
#       candidate_work_phone_home_phone_fax  \
# id
# 17268                                 NaN
# 15508                                 NaN
# ...                                   ...
# 17425         (503)397-3023 (503)397-0181
# 13147                                 NaN
#
#                                candidate_mailing_address  \
# id
# 17268                                                NaN
# 15508                                                NaN
# ...                                                  ...
# 17425  59157 Cooperspur CT Saint Helens, OR 97051 - 9311
# 13147                                                NaN
#
#       candidate_email_address candidate_occupation candidate_employer  \
# id
# 17268                     NaN                  NaN                NaN
# 15508                     NaN                  NaN                NaN
# ...                       ...                  ...                ...
# 17425       rbraud6@gmail.com         Not Employed                NaN
# 13147                     NaN                  NaN                NaN
#
#       measure_election measure_support measure_details committee_type
# id
# 17268              NaN             NaN             NaN            PAC
# 15508              NaN             NaN             NaN            PAC
# ...                ...             ...             ...            ...
# 17425              NaN             NaN             NaN             CC
# 13147              NaN             NaN             NaN            PAC
#
# [1415 rows x 24 columns]

# %%
candidates
# Out:
#                        election_year          office_group  id_nbr  \
# election_txt
# 2014 General Election           2014     US Representative     303
# 2014 General Election           2014     US Representative     304
# ...                              ...                   ...     ...
# 2008 Primary Election           2008  State Representative    1253
# 2008 Primary Election           2008  State Representative    1226
#
#                               office                     candidate_office  \
# election_txt
# 2014 General Election   3rd District      US Representative, 3rd District
# 2014 General Election   4th District      US Representative, 4th District
# ...                              ...                                  ...
# 2008 Primary Election  53rd District  State Representative, 53rd District
# 2008 Primary Election  26th District  State Representative, 26th District
#
#                        candidate_file_rsn file_mthd_ind filetype_descr  \
# election_txt
# 2014 General Election               15772             P    Minor Party
# 2014 General Election               15773             P    Minor Party
# ...                                   ...           ...            ...
# 2008 Primary Election                 221             P            Fee
# 2008 Primary Election                  41             W            Fee
#
#                         party_descr major_party_ind  \
# election_txt
# 2014 General Election  Constitution               N
# 2014 General Election   Progressive               N
# ...                             ...             ...
# 2008 Primary Election    Republican               Y
# 2008 Primary Election    Republican               Y
#
#                                   ...             residence_city_name  \
# election_txt                      ...
# 2014 General Election             ...                        Portland
# 2014 General Election             ...                             NaN
# ...                               ...                             ...
# 2008 Primary Election             ...                        Sunriver
# 2008 Primary Election             ...                     Wilsonville
#
#                       residence_st_cd residence_zip_code  \
# election_txt
# 2014 General Election              OR              97214
# 2014 General Election             NaN                NaN
# ...                               ...                ...
# 2008 Primary Election              OR              97707
# 2008 Primary Election              OR              97070
#
#                       residence_zip_plus_four     home_phone     cell_phone  \
# election_txt
# 2014 General Election                     NaN  (503)314-6597  (503)314-6597
# 2014 General Election                     NaN            NaN            NaN
# ...                                       ...            ...            ...
# 2008 Primary Election                     NaN  (541)598-7560            NaN
# 2008 Primary Election                     NaN  (503)351-2955            NaN
#
#                            fax_phone                            email  \
# election_txt
# 2014 General Election  (503)573-1936                jbuchal@mbllp.com
# 2014 General Election            NaN  campaign@defazioforcongress.org
# ...                              ...                              ...
# 2008 Primary Election            NaN               electgenew@msn.com
# 2008 Primary Election  (509)479-6170          wingardreport@yahoo.com
#
#                           work_phone                 web_address
# election_txt
# 2014 General Election  (503)227-1011              www.buchal.com
# 2014 General Election  (541)485-1622  www.defazioforcongress.org
# ...                              ...                         ...
# 2008 Primary Election            NaN        www.genewhisnant.com
# 2008 Primary Election  (503)351-2955         www.MattWingard.com
#
# [2353 rows x 51 columns]

# %%
# Thanks
pd.set_option("display.max_rows",101)

# %% [markdown]
# # Vectorizing
# Thanks [@larsmans](http://stackoverflow.com/users/166749/larsmans)
# for a speedy [stemming vectorizer](http://stackoverflow.com/a/26212970/623735)

# %%
# !pip install pystemmer
import Stemmer
english_stemmer = Stemmer.Stemmer('en')
class StemmedTfidfVectorizer(TfidfVectorizer):
    def build_analyzer(self):
        analyzer = super(TfidfVectorizer, self).build_analyzer()
        return lambda doc: english_stemmer.stemWords(analyzer(doc))
     
tfidf = StemmedTfidfVectorizer(min_df=1, stop_words='english', analyzer='word', ngram_range=(1, 2))
