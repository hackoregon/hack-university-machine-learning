# %%
import slacker
slacker.Users?

# %%
u = slacker.Users(token='xoxb-20691123250-knnFIQfvlCloBOhy7wT2v88t')
u?
u??

# %%
users.list()

# %%
response = u.list()
response??

# %%
response.body
# Out:
# {u'cache_ts': 1456079209,
#  u'members': [{u'color': u'3c8c69',
#    u'deleted': False,
#    u'id': u'U0MACP8QY',
#    u'is_admin': False,
#    u'is_bot': False,
#    u'is_owner': False,
#    u'is_primary_owner': False,
#    u'is_restricted': False,
#    u'is_ultra_restricted': False,
#    u'name': u'1am5teph',
#    u'profile': {u'avatar_hash': u'g8d70af86a21',
#     u'email': u'marson.stephanie@gmail.com',
#     u'image_192': u'https://secure.gravatar.com/avatar/8d70af86a21661b79910cd02f7e9fc38.jpg?s=192&d=https%3A%2F%2Fslack.global.ssl.fastly.net%2F7fa9%2Fimg%2Favatars%2Fava_0018-192.png',
#     u'image_24': u'https://secure.gravatar.com/avatar/8d70af86a21661b79910cd02f7e9fc38.jpg?s=24&d=https%3A%2F%2Fslack.global.ssl.fastly.net%2F66f9%2Fimg%2Favatars%2Fava_0018-24.png',
#     u'image_32': u'https://secure.gravatar.com/avatar/8d70af86a21661b79910cd02f7e9fc38.jpg?s=32&d=https%3A%2F%2Fslack.global.ssl.fastly.net%2F66f9%2Fimg%2Favatars%2Fava_0018-32.png',
# ...

# %%
for member in response.body['members']:
    print member['name'] + ': ' + member.get('real_name', 'UNKNOWN NAME') + ': ' + member.get('title', 'UNKOWN TITLE')
# Out:
# 1am5teph: : UNKOWN TITLE
# amy: : UNKOWN TITLE
# angelahill: Angela Hill: UNKOWN TITLE
# aurelia: : UNKOWN TITLE
# billmcgair: Bill McGair: UNKOWN TITLE
# birajbisht: : UNKOWN TITLE
# brycejohnson: : UNKOWN TITLE
# buddy: Buddy Bot: UNKOWN TITLE
# catnik: : UNKOWN TITLE
# cristovu: : UNKOWN TITLE
# d-diaz: : UNKOWN TITLE
# david: : UNKOWN TITLE
# dpcairns: Danny Cairns: UNKOWN TITLE
# dpearl: : UNKOWN TITLE
# eliza: ELIZA Bot: UNKOWN TITLE
# eric_ebbott: Eric Ebbott: UNKOWN TITLE
# grace-andrews: : UNKOWN TITLE
# heidi: : UNKOWN TITLE
# hobs: Hobson Lane: UNKOWN TITLE
# jbizjak: : UNKOWN TITLE
# jethard: : UNKOWN TITLE
# jzimm: John Zimmerman: UNKOWN TITLE
# kjypdx: : UNKOWN TITLE
# lindsaymico: : UNKOWN TITLE
# lorenguerriero: : UNKOWN TITLE
# maryannet: Mary Anne Thygesen: UNKOWN TITLE
# maw22: Mark Wheeler: UNKOWN TITLE
# meganmckissack: : UNKOWN TITLE
# moorman: : UNKOWN TITLE
# morgan: : UNKOWN TITLE
# nkanderson: : UNKOWN TITLE
# nophska: Allyson  Nophsker: UNKOWN TITLE
# ...

# %%
for member in response.body['members']:
    print member['name'] + ': ' + member.get('real_name', '') + ': ' + member.get('profile', {}).get('title', "")
# Out:
# 1am5teph: :
# amy: :
# angelahill: Angela Hill:
# aurelia: :
# billmcgair: Bill McGair: DevOps/Developer
# birajbisht: :
# brycejohnson: :
# buddy: Buddy Bot: Machine Learning classroom TA
# catnik: :
# cristovu: :
# d-diaz: :
# david: :
# dpcairns: Danny Cairns: I'm taking the Dev Ops course!
# dpearl: :
# eliza: ELIZA Bot: Grades quizzes, and generally entertains us with its curiosity, like the original ELIZA
# eric_ebbott: Eric Ebbott:
# grace-andrews: :
# heidi: :
# hobs: Hobson Lane: Machine Intelligence
# jbizjak: :
# jethard: :
# jzimm: John Zimmerman: DevOps @ TriMet
# kjypdx: :
# lindsaymico: :
# lorenguerriero: :
# maryannet: Mary Anne Thygesen: Data Science
# maw22: Mark Wheeler:
# meganmckissack: :
# moorman: :
# morgan: :
# nkanderson: :
# nophska: Allyson  Nophsker: Business Systems Analyst
# ramonpichardo: Ramon Pichardo:
# riley: :
# robthehall: Robert Hall:
# sandeshadhikary: :
# sarasarasara: Sara Fen:
# smullen: :
# stephany.garcia: :
# strachan: :
# subcurrent: :
# ...

# %%
ch = slacker.Channels(token='xoxb-20691123250-knnFIQfvlCloBOhy7wT2v88t')
ch.history
# Out:
# <bound method Channels.history of <slacker.Channels object at 0x7fc9f8103790>>

# %%
ch.history()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-e8d50b10cb97> in <module>()
# ----> 1 ch.history()
#
# TypeError: history() takes at least 2 arguments (1 given)

# %%
ch.history?

# %%
ch.history(channel='C0LL5MDKN')

# %%
ch.history(channel='C0LL5MDKN').body
# Out:
# {u'has_more': False,
#  u'messages': [{u'text': u'<@U0LR97J6M>: Hi',
#    u'ts': u'1456075787.000008',
#    u'type': u'message',
#    u'user': u'U0LL6QSP9'},
#   {u'text': u'<@U0LLB3M7C>: Hi',
#    u'ts': u'1456075780.000007',
#    u'type': u'message',
#    u'user': u'U0LL6QSP9'},
#   {u'text': u'<@U0LL13TNV>:  Thanks, see ya soon',
#    u'ts': u'1456075460.000006',
#    u'type': u'message',
#    u'user': u'U0LL6QSP9'},
#   {u'text': u'<@U0LR97J6M>: This is a test',
#    u'ts': u'1456075442.000005',
#    u'type': u'message',
#    u'user': u'U0LL6QSP9'},
#   {u'text': u'<@U0LL6QSP9> we can spend some time in class together working on it. that code is really hard to read.',
#    u'ts': u'1456075024.000004',
#    u'type': u'message',
#    u'user': u'U0LL13TNV'},
#   {u'text': u'<@U0LR97J6M>: Hello?',
#    u'ts': u'1456074156.000003',
#    u'type': u'message',
#    u'user': u'U0LL6QSP9'},
#   {u'text': u'<@U0LR97J6M>: can you hear me?',
#    u'ts': u'1456074062.000002',
# ...

# %%
for msg in ch.history(channel='C0LL5MDKN').body['messages']:
    print msg.get('text', 'NOTHING')
# Out:
# <@U0LR97J6M>: Hi
# <@U0LLB3M7C>: Hi
# <@U0LL13TNV>:  Thanks, see ya soon
# <@U0LR97J6M>: This is a test
# <@U0LL6QSP9> we can spend some time in class together working on it. that code is really hard to read.
# <@U0LR97J6M>: Hello?
# <@U0LR97J6M>: can you hear me?
# hi
# hey
# ??
# I'm alive!
# <@U0LLB3M7C>: what's up
# <@U0LLB3M7C>: Hello
# hello
# I'm alive!
# <@U0LL6QSP9|zakkent> has joined the channel
# hello
# <@U0N3U0KFH|jbizjak> has joined the channel
# <@U0LNNUDGF|lindsaymico> has joined the channel
# <@U0MFFA6R2|jethard> has joined the channel
# <@U0MSMLTM4|strachan> has joined the channel
# <@U0LLAU2E9|birajbisht> has joined the channel
# I'm alive!
# Received 'How's it going Eliza?' in channel 'C0LL5MDKN' at 1455775843.86
# How's it going Eliza?
# <@U0LLB3M7C>: are you there?
# I'm alive!
# I'm alive!
# I'm alive!
# I'm alive!
# I'm alive!
# I'm alive!
# I'm alive!
# I'm alive!
# *Can you `import pandas`*
#
# :one:Yes
# :two:No
#
#
# *What is your OS?*
#
# :one:Mac
# ...
